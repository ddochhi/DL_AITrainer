# %%
import os
import json
import pandas as pd
import cv2
import mediapipe as mp

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/489-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/490-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/491-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/492-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/493-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/494-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/495-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/496-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/497-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/498-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/499-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/500-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/501-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/502-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/503-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
# 폴더 경로 설정
folder_path = '/Users/gwon-yeonghyeon/Desktop/Day34_201106_F/1/A/504-1-2-22-Z37_A'

# mediapipe 초기화
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# # 데이터프레임 생성
# df = pd.DataFrame(columns=["Image_Name", "Landmark", "X", "Y"])

# 폴더 내의 모든 JPG 파일에 대해 반복
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        # 이미지 파일 경로 생성
        image_path = os.path.join(folder_path, filename)

        # 이미지 열기
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # mediapipe 포즈 인식을 위한 인스턴스 설정
        with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # 이미지를 RGB 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Make detection
            results = pose.process(image)

            # 이미지를 BGR 색상 모드로 변환
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 포즈 랜드마크를 시각화 -> 이미지에 렌더링
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            )

            # 이미지를 화면에 표시
            cv2.imshow('Mediapipe Feed', image)
            cv2.waitKey(0)  # 이미지 창을 열어둔 상태에서 키 입력을 대기합니다.
            cv2.destroyAllWindows()  # 이미지 창을 닫습니다.

            # 랜드마크 데이터를 데이터프레임에 추가
            if results.pose_landmarks:
                for idx, landmark in enumerate(results.pose_landmarks.landmark):
                    # 랜드마크의 이름, 좌표, 이미지 이름을 데이터프레임에 추가
                    row = ['plank', mp_pose.PoseLandmark(idx).name, landmark.x, landmark.y]
                    df.loc[len(df)] = row

# %%
df['Image_Name'] = 'crunch'
df
# Out:
#       Image_Name          Landmark         X         Y
# 0         crunch              NOSE  0.616662  0.549175
# 1         crunch    LEFT_EYE_INNER  0.622938  0.553962
# 2         crunch          LEFT_EYE  0.623152  0.556015
# 3         crunch    LEFT_EYE_OUTER  0.623366  0.558000
# 4         crunch   RIGHT_EYE_INNER  0.623387  0.552272
# ...          ...               ...       ...       ...
# 16891     crunch       RIGHT_ANKLE  0.494729  0.539278
# 16892     crunch         LEFT_HEEL  0.488297  0.544079
# 16893     crunch        RIGHT_HEEL  0.503988  0.548630
# 16894     crunch   LEFT_FOOT_INDEX  0.466703  0.556739
# 16895     crunch  RIGHT_FOOT_INDEX  0.482536  0.554353
#
# [16896 rows x 4 columns]

# %%
# DataFrame을 CSV 파일로 저장
csv_path = "crunch.csv"
df.to_csv(csv_path, index=False)
print(f"Pose landmarks for all images saved to {csv_path}")
# Out:
# Pose landmarks for all images saved to crunch.csv

# %%
import matplotlib.pyplot as plt

plt.scatter(df['X'],df['Y'])

# %%
plt.boxplot(df['X'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17ff74610>,
#   <matplotlib.lines.Line2D at 0x17ff748b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x17ff74b50>,
#   <matplotlib.lines.Line2D at 0x17ff74df0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x17ff74370>],
#  'medians': [<matplotlib.lines.Line2D at 0x17ff75090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17ff75330>],
#  'means': []}

# %%
plt.boxplot(df['Y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17ff233d0>,
#   <matplotlib.lines.Line2D at 0x17ff23670>],
#  'caps': [<matplotlib.lines.Line2D at 0x17ff23910>,
#   <matplotlib.lines.Line2D at 0x17ff23bb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x17ff23130>],
#  'medians': [<matplotlib.lines.Line2D at 0x17ff23e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x298110130>],
#  'means': []}
