# %%
import cv2
import os

# Input video file path
video_path = '/Users/junheehan/Library/CloudStorage/OneDrive-Personal/Jun/핀테크/기계학습과딥러닝_이재욱/deep_learning_motion_detection/crunch.mov'

# Output folder to save frames as PNG files
output_folder = 'crunch'

# Desired frame rate (10 FPS)
desired_fps = 10

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the original frame rate of the video
original_fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f'Original frame rate of the video: {original_fps} FPS')

# Calculate the frame interval to achieve the desired frame rate
frame_interval = int(original_fps / desired_fps)

# Initialize frame count
frame_count = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if we have reached the end of the video
    if not ret:
        break

    # Only save frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Define the path to save the frame as a PNG file
        frame_path = os.path.join(output_folder, f'frame_{frame_count:04d}.png')

        # Save the frame as a PNG file
        cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f'{frame_count} frames extracted and saved to {output_folder} at {desired_fps} FPS')
# Out:
# Original frame rate of the video: 29 FPS
# 1040 frames extracted and saved to crunch at 10 FPS

# %%
# Input video file path
video_path = '/Users/junheehan/Library/CloudStorage/OneDrive-Personal/Jun/핀테크/기계학습과딥러닝_이재욱/deep_learning_motion_detection/leg_raise.mov'

# Output folder to save frames as PNG files
output_folder = 'raise'

# Desired frame rate (10 FPS)
desired_fps = 10

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the original frame rate of the video
original_fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f'Original frame rate of the video: {original_fps} FPS')

# Calculate the frame interval to achieve the desired frame rate
frame_interval = int(original_fps / desired_fps)

# Initialize frame count
frame_count = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if we have reached the end of the video
    if not ret:
        break

    # Only save frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Define the path to save the frame as a PNG file
        frame_path = os.path.join(output_folder, f'frame_{frame_count:04d}.png')

        # Save the frame as a PNG file
        cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f'{frame_count} frames extracted and saved to {output_folder} at {desired_fps} FPS')
# Out:
# Original frame rate of the video: 29 FPS
# 1511 frames extracted and saved to raise at 10 FPS

# %%
# Input video file path
video_path = '/Users/junheehan/Library/CloudStorage/OneDrive-Personal/Jun/핀테크/기계학습과딥러닝_이재욱/deep_learning_motion_detection/lunge.mov'

# Output folder to save frames as PNG files
output_folder = 'lunge'

# Desired frame rate (10 FPS)
desired_fps = 10

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the original frame rate of the video
original_fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f'Original frame rate of the video: {original_fps} FPS')

# Calculate the frame interval to achieve the desired frame rate
frame_interval = int(original_fps / desired_fps)

# Initialize frame count
frame_count = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if we have reached the end of the video
    if not ret:
        break

    # Only save frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Define the path to save the frame as a PNG file
        frame_path = os.path.join(output_folder, f'frame_{frame_count:04d}.png')

        # Save the frame as a PNG file
        cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f'{frame_count} frames extracted and saved to {output_folder} at {desired_fps} FPS')
# Out:
# Original frame rate of the video: 29 FPS
# 1846 frames extracted and saved to lunge at 10 FPS

# %%
# Input video file path
video_path = '/Users/junheehan/Library/CloudStorage/OneDrive-Personal/Jun/핀테크/기계학습과딥러닝_이재욱/deep_learning_motion_detection/plank.mov'

# Output folder to save frames as PNG files
output_folder = 'plank'

# Desired frame rate (10 FPS)
desired_fps = 10

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the original frame rate of the video
original_fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f'Original frame rate of the video: {original_fps} FPS')

# Calculate the frame interval to achieve the desired frame rate
frame_interval = int(original_fps / desired_fps)

# Initialize frame count
frame_count = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if we have reached the end of the video
    if not ret:
        break

    # Only save frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Define the path to save the frame as a PNG file
        frame_path = os.path.join(output_folder, f'frame_{frame_count:04d}.png')

        # Save the frame as a PNG file
        cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f'{frame_count} frames extracted and saved to {output_folder} at {desired_fps} FPS')
# Out:
# Original frame rate of the video: 29 FPS
# 2045 frames extracted and saved to plank at 10 FPS

# %%
# Input video file path
video_path = '/Users/junheehan/Library/CloudStorage/OneDrive-Personal/Jun/핀테크/기계학습과딥러닝_이재욱/deep_learning_motion_detection/push_up.mov'

# Output folder to save frames as PNG files
output_folder = 'up'

# Desired frame rate (10 FPS)
desired_fps = 10

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the original frame rate of the video
original_fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f'Original frame rate of the video: {original_fps} FPS')

# Calculate the frame interval to achieve the desired frame rate
frame_interval = int(original_fps / desired_fps)

# Initialize frame count
frame_count = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if we have reached the end of the video
    if not ret:
        break

    # Only save frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Define the path to save the frame as a PNG file
        frame_path = os.path.join(output_folder, f'frame_{frame_count:04d}.png')

        # Save the frame as a PNG file
        cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f'{frame_count} frames extracted and saved to {output_folder} at {desired_fps} FPS')
# Out:
# Original frame rate of the video: 29 FPS
# 1301 frames extracted and saved to up at 10 FPS

# %%
# Input video file path
video_path = '/Users/junheehan/Library/CloudStorage/OneDrive-Personal/Jun/핀테크/기계학습과딥러닝_이재욱/deep_learning_motion_detection/squat.mov'

# Output folder to save frames as PNG files
output_folder = 'squat'

# Desired frame rate (10 FPS)
desired_fps = 10

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the original frame rate of the video
original_fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f'Original frame rate of the video: {original_fps} FPS')

# Calculate the frame interval to achieve the desired frame rate
frame_interval = int(original_fps / desired_fps)

# Initialize frame count
frame_count = 0

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if we have reached the end of the video
    if not ret:
        break

    # Only save frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Define the path to save the frame as a PNG file
        frame_path = os.path.join(output_folder, f'frame_{frame_count:04d}.png')

        # Save the frame as a PNG file
        cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f'{frame_count} frames extracted and saved to {output_folder} at {desired_fps} FPS')
# Out:
# Original frame rate of the video: 29 FPS
# 1865 frames extracted and saved to squat at 10 FPS
