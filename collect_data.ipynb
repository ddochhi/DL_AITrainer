# %% [markdown]
# # biceps curl, squat 동작 학습 및 구분

# %% [markdown]
# ## 스쿼트

# %%
# !pip install pandas==1.3.5
# Out:
# Collecting pandas==1.3.5
#   Downloading pandas-1.3.5-cp310-cp310-macosx_11_0_arm64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 8.9 MB/s eta 0:00:0000:010:01m
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/gwon-yeonghyeon/anaconda3/envs/DL/lib/python3.10/site-packages (from pandas==1.3.5) (2.8.2)
# Collecting pytz>=2017.3 (from pandas==1.3.5)
#   Obtaining dependency information for pytz>=2017.3 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/gwon-yeonghyeon/anaconda3/envs/DL/lib/python3.10/site-packages (from pandas==1.3.5) (1.25.2)
# Requirement already satisfied: six>=1.5 in /Users/gwon-yeonghyeon/anaconda3/envs/DL/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.16.0)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.3.5 pytz-2023.3.post1

# %%
import mediapipe as mp
import cv2
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# Drawing helpers
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
df = pd.DataFrame(columns=["label", "left_shoulder_x","left_shoulder_y","right_shoulder_x","right_shoulder_y",
                           "left_elbow_x","left_elbow_y","right_elbow_x","right_elbow_y",
                           "left_wrist_x","left_wrist_y","right_wrist_x","right_wrist_y",
                           "left_hip_x","left_hip_y","right_hip_x","right_hip_y",
                            "left_knee_x","left_knee_y","right_knee_x","right_knee_y",
                            "left_ankle_x","left_ankle_y","right_ankle_x","right_ankle_y"])
df
# Out:
# Empty DataFrame
# Columns: [label, left_shoulder_x, left_shoulder_y, right_shoulder_x, right_shoulder_y, left_elbow_x, left_elbow_y, right_elbow_x, right_elbow_y, left_wrist_x, left_wrist_y, right_wrist_x, right_wrist_y, left_hip_x, left_hip_y, right_hip_x, right_hip_y, left_knee_x, left_knee_y, right_knee_x, right_knee_y, left_ankle_x, left_ankle_y, right_ankle_x, right_ankle_y]
# Index: []
#
# [0 rows x 25 columns]

# %%
cap = cv2.VideoCapture("mp4/squat.mp4")

current_stage = ""
prediction_probability_threshold = 0.8

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, image = cap.read()

        if not ret:
            break

        # Recolor image from BGR to RGB for mediapipe
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = pose.process(image)
        # Calculate and compare the distance of 2 ankle and shoulder width
        if not results.pose_landmarks:
            continue
        
        # Recolor image from BGR to RGB for mediapipe
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)


        try:
            # # Extract keypoints from frame for the input
            # row = extract_important_keypoints(results)
            # X = pd.DataFrame([row], columns=headers[1:])

            # # Make prediction and its probability
            # predicted_class = trained_model.predict(X)[0]
            # prediction_probability = trained_model.predict_proba(X)[0]

            # # Evaluate model prediction for the current stage
            # if prediction_probability[prediction_probability.argmax()] >= prediction_probability_threshold:
            #     if predicted_class == "down":
            #         current_stage = "down"
            #     elif current_stage == "middle" and predicted_class == "up":
            #         current_stage = "up"
            # else:
            #     current_stage = "middle"
            
            # Calculate and compare the distance of 2 ankle and shoulder width
            landmarks = results.pose_landmarks.landmark

            # * Calculate shoulder width
            left_shoulder_x = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x
            left_shoulder_y = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y

            right_shoulder_x = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x
            right_shoulder_y = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y

            # * Calculate elbow width
            left_elbow_x = landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x
            left_elbow_y = landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y

            right_elbow_x = landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x
            right_elbow_y = landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y

            # * Calculate wrist width
            left_wrist_x = landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x
            left_wrist_y = landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y

            right_wrist_x = landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x
            right_wrist_y = landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y

            # * Calculate hip width
            left_hip_x = landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x
            left_hip_y = landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y

            right_hip_x = landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x
            right_hip_y = landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y

            # * Calculate 2-knee width
            left_knee_x = landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x
            left_knee_y = landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y
            
            right_knee_x = landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x
            right_knee_y = landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y

            # * Calculate 2-ankle width
            left_ankle_x = landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x
            left_ankle_y = landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y

            right_ankle_x = landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x
            right_ankle_y = landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y



            # # Visualization
            # # Status box
            # cv2.rectangle(image, (0, 0), (500, 60), (245, 117, 16), -1)

            # # Display feet distance
            # cv2.putText(image, "ANKLE", (15, 12), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            # cv2.putText(image, str(round(left_ankle, 2)), (10, 40), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            # # Display shoulder distance
            # cv2.putText(image, "HIP", (95, 12), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            # cv2.putText(image, str(round(left_hip, 2)), (90, 40), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            # # Display knee distance
            # cv2.putText(image, "KNEE", (205, 12), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            # cv2.putText(image, str(round(left_knee, 2)), (200, 40), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            # # Display knee distance
            # cv2.putText(image, "STAGE", (305, 12), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            # cv2.putText(image, current_stage, (300, 40), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        except Exception as e:
            print(f"Error: {e}")

        # Draw landmarks and connections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        cv2.imshow("CV2", image)

        # Pressed key for action
        k = cv2.waitKey(1) & 0xFF

        # Press C to add to df
        if k == ord('c'): 
            df = df.append({ "label": 'squat', "left_hip_x": left_hip_x,"left_hip_y": left_hip_y, "right_hip_x": right_hip_x,"right_hip_y": right_hip_y,
                            "left_shoulder_x": left_shoulder_x,"left_shoulder_y": left_shoulder_y, "right_shoulder_x": right_shoulder_x,"right_shoulder_y": right_shoulder_y,
                             "left_elbow_x": left_elbow_x,"left_elbow_y": left_elbow_y, "right_elbow_x": right_elbow_x,"right_elbow_y": right_elbow_y,
                             "left_wrist_x": left_wrist_x,"left_wrist_y": left_wrist_y, "right_wrist_x": right_wrist_x,"right_wrist_y": right_wrist_y,
                             "left_knee_x": left_knee_x,"left_knee_y": left_knee_y, "right_knee_x": right_knee_x,"right_knee_y": right_knee_y,
                            "left_ankle_x": left_ankle_x,"left_ankle_y": left_ankle_y, "right_ankle_x": right_ankle_x, "right_ankle_y": right_ankle_y }, ignore_index=True)

        # Press q to stop
        elif k == ord("q"):
            break
        else: continue

    cap.release()
    cv2.destroyAllWindows()

    # (Optional)Fix bugs cannot close windows in MacOS (https://stackoverflow.com/questions/6116564/destroywindow-does-not-close-window-on-mac-using-python-and-opencv)
    for i in range (1, 5):
        cv2.waitKey(1)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# Error: LEFT_SOULDER
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 125
#     123 # Press C to add to df
#     124 if k == ord('c'):
# --> 125     df = df.append({ "label": 'squat', "left_hip_x": left_hip_x,"left_hip_y": left_hip_y, "right_hip_x": right_hip_x,"right_hip_y": right_hip_y,
#     126                     "left_shoulder_x": left_shoulder_x,"left_shoulder_y": left_shoulder_y, "right_shoulder_x": right_shoulder_x,"right_shoulder_y": right_shoulder_y,
#     127                      "left_elbow_x": left_elbow_x,"left_elbow_y": left_elbow_y, "right_elbow_x": right_elbow_x,"right_elbow_y": right_elbow_y,
#     128                      "left_wrist_x": left_wrist_x,"left_wrist_y": left_wrist_y, "right_wrist_x": right_wrist_x,"right_wrist_y": right_wrist_y,
#     129                      "left_knee_x": left_knee_x,"left_knee_y": left_knee_y, "right_knee_x": right_knee_x,"right_knee_y": right_knee_y,
#     130                     "left_ankle_x": left_ankle_x,"left_ankle_y": left_ankle_y, "right_ankle_x": right_ankle_x, "right_ankle_y": right_ankle_y }, ignore_index=True)
#     132 # Press q to stop
#     133 elif k == ord("q"):
#
# NameError: name 'left_hip_x' is not defined

# %%
df
# Out:
#      label  left_hip_x  left_hip_y  right_hip_x  right_hip_y  left_knee_x  \
# 0    squat    0.564162    0.743463     0.524189     0.749038     0.523885
# 1    squat    0.563850    0.702074     0.524936     0.713164     0.525416
# 2    squat    0.560400    0.645544     0.521902     0.656400     0.531360
# 3    squat    0.559769    0.619289     0.521022     0.627455     0.534835
# 4    squat    0.555258    0.571471     0.519190     0.580954     0.541122
# ..     ...         ...         ...          ...          ...          ...
# 125  squat    0.568446    0.745138     0.528780     0.748537     0.524750
# 126  squat    0.565228    0.680079     0.525966     0.689884     0.526972
# 127  squat    0.559682    0.618670     0.520997     0.625755     0.536938
# 128  squat    0.552372    0.570034     0.516729     0.578222     0.541363
# 129  squat    0.539603    0.538173     0.503429     0.544088     0.542261
#
#      left_knee_y  right_knee_x  right_knee_y  left_ankle_x  left_ankle_y  \
# 0       0.748917      0.444979      0.746916      0.547937      0.904186
# 1       0.743046      0.445470      0.744888      0.549049      0.904504
# 2       0.738328      0.448259      0.739098      0.549416      0.903177
# 3       0.740966      0.453733      0.729360      0.549606      0.903129
# 4       0.737642      0.465142      0.720470      0.550879      0.902456
# ..           ...           ...           ...           ...           ...
# 125     0.748781      0.446071      0.743332      0.549110      0.905377
# 126     0.734917      0.447182      0.739796      0.549166      0.901846
# 127     0.735474      0.455027      0.729115      0.549499      0.902461
# 128     0.733461      0.465669      0.717982      0.550762      0.902275
# 129     0.719239      0.479825      0.715576      0.550982      0.898603
#
#      right_ankle_x  right_ankle_y
# 0         0.481289       0.885275
# 1         0.481200       0.884055
# 2         0.482496       0.883690
# 3         0.483241       0.884800
# 4         0.483381       0.884859
# ..             ...            ...
# 125       0.481177       0.884606
# 126       0.482928       0.884933
# 127       0.483894       0.886105
# 128       0.483455       0.885809
# 129       0.484772       0.884447
#
# [130 rows x 13 columns]

# %%
df.to_csv('squat_data.csv', index=False)
